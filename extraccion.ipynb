# %% [markdown]
# # Actualización

# %%
import pandas as pd

# %%
import requests
import json

url = "https://api.biblioteca.mtt.gob.cl/v1/graphql"

payload = "{\"query\":\"query FindFOProgramReportByID($id: uuid!) {\\n  program_report_by_pk(id: $id) {\\n    id\\n    name\\n    description\\n    category {\\n      id\\n      name\\n      __typename\\n    }\\n    category_data\\n    frequent_category {\\n      id\\n      name\\n      __typename\\n    }\\n    program {\\n      id\\n      name\\n      abbreviation\\n      __typename\\n    }\\n    program_files {\\n      id\\n      name\\n      storage_type\\n      file_data\\n      __typename\\n    }\\n    created_at\\n    updated_at\\n    __typename\\n  }\\n}\",\"variables\":{\"id\":\"4ae5c805-83bd-440d-b3f4-37d98c2103cf\"}}"
headers = {
  'accept': '*/*',
  'accept-language': 'es-ES,es;q=0.9,en;q=0.8,pt;q=0.7',
  'content-type': 'application/json',
  'origin': 'https://biblioteca.mtt.gob.cl',
  'priority': 'u=1, i',
  'referer': 'https://biblioteca.mtt.gob.cl/',
  'sec-ch-ua': '"Chromium";v="142", "Google Chrome";v="142", "Not_A Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-site',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"data":{"program_report_by_pk":{"id":"4ae5c805-83bd-440d-b3f4-37d98c2103cf","name":"Base de Datos de Transporte Público","description":"La información publicada corresponde a la de servicios activos, incluyendo datos de responsables de servicios, representantes legales, vehículos, recorridos y trazados, todos vigentes en el Registro Nacional de Servicios de Transporte de Pasajeros a nivel nacional, para el mes y año que se informa.","category":{"id":"study_document.v1","name":"estudios y documentos","__typename":"category"},"category_data":{"document_date": "2025-08-29T04:00:00.000Z", "mandate_holder": ["División de Normas y Operaciones"], "consultant_author": ["Unidad de Registro"]},"frequent_category":{"id":"a0c21f37-196f-43e5-bbe9-0d4015ef35da","name":"BASE DE DATOS TRANSPORTE PUBLICO","__typename":"frequent_category"},"program":{"id":"3fde214a-af6f-41f6-86a4-37f7bb08e41d","name":"División de Normas y Operaciones","abbreviation":"DNO","__typename":"program"},"program_files":[{"id
# ...

# %%
response_json = response.json()

# %%
response_json
# Out:
# {'data': {'program_report_by_pk': {'id': '4ae5c805-83bd-440d-b3f4-37d98c2103cf',
#    'name': 'Base de Datos de Transporte Público',
#    'description': 'La información publicada corresponde a la de servicios activos, incluyendo datos de responsables de servicios, representantes legales, vehículos, recorridos y trazados, todos vigentes en el Registro Nacional de Servicios de Transporte de Pasajeros a nivel nacional, para el mes y año que se informa.',
#    'category': {'id': 'study_document.v1',
#     'name': 'estudios y documentos',
#     '__typename': 'category'},
#    'category_data': {'document_date': '2025-08-29T04:00:00.000Z',
#     'mandate_holder': ['División de Normas y Operaciones'],
#     'consultant_author': ['Unidad de Registro']},
#    'frequent_category': {'id': 'a0c21f37-196f-43e5-bbe9-0d4015ef35da',
#     'name': 'BASE DE DATOS TRANSPORTE PUBLICO',
#     '__typename': 'frequent_category'},
#    'program': {'id': '3fde214a-af6f-41f6-86a4-37f7bb08e41d',
# ...

# %%
program_files = response_json["data"]["program_report_by_pk"]["program_files"]

# %%
años_links = [
    {
        "year": pf["name"],
        "url": pf["file_data"]["fileUrl"]
    }
    for pf in program_files
]
años_links
# Out:
# [{'year': 'Año 2025',
#   'url': 'https://drive.google.com/drive/folders/1l7qZb81t-cDIUlkapCpHO5RY7-CmpevB?usp=drive_link'},
#  {'year': 'Año 2024',
#   'url': 'https://drive.google.com/drive/folders/1AJlQfxJveEyYqPEKQbu7Odf97ZqRSUKO?usp=drive_link'},
#  {'year': 'Año 2023',
#   'url': 'https://drive.google.com/drive/folders/1FXcud5vFlefjpHB09NODtjWA1g20-Je_?usp=drive_link'},
#  {'year': 'Año 2022',
#   'url': 'https://drive.google.com/drive/folders/1Mx9XfFQz9aFH7rUo4uR0RxkvUqW1GL3z?usp=drive_link'},
#  {'year': 'Año 2021',
#   'url': 'https://drive.google.com/drive/folders/1geE7gL-R6m1UmYdtgfKSQ0H76iuUlXHp?usp=drive_link'},
#  {'year': 'Año 2020',
#   'url': 'https://drive.google.com/drive/folders/1vjRX_OK8s6vGJnktKjo5Fb2RBlJ45hQa?usp=drive_link'},
#  {'year': 'Año 2019 - 2012',
#   'url': 'https://drive.google.com/drive/folders/10KosY1SsboYG4fEhnh72cbOM2Z4ZkgEI?usp=drive_link'}]
