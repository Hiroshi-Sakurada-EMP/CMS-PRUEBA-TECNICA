# %% [markdown]
# # Imports

# %%
import pandas as pd
import re
import os

# %% [markdown]
# # lectura

# %% [markdown]
# # funciones

# %%
# 

root_excels = "C:\\Users\\hsakurada\\Desktop\\ESTUDIO\\wea\\CMS-PRUEBA-TECNICA\\descargas"

MESES = {
    "enero": 1, "febrero": 2, "marzo": 3, "abril": 4,
    "mayo": 5, "junio": 6, "julio": 7, "agosto": 8,
    "septiembre": 9, "octubre": 10, "noviembre": 11, "diciembre": 12
}
años = ['2025','2024','2023','2022','2021','2020','2019','2018','2017','2016','2015','2014','2013','2012','2011','2010']

# %%
def extraer_mes_nomb_excel(nombre_archivo):
    # quitar extensión
    nombre = os.path.splitext(nombre_archivo)[0].lower()

    # separar por espacios, guiones, underscores, etc.
    partes = re.split(r"[ _\-]+", nombre)

    # buscar coincidencia exacta
    for parte in partes:
        if parte in MESES:
            return parte  # retorna el nombre del mes encontrado

    # búsqueda más flexible: " - diciembre 2012"
    for mes in MESES:
        if mes in nombre:
            return mes

    return None


def extraer_año(nombre_archivo):
    
    # quitar extensión
    nombre = os.path.splitext(nombre_archivo)[0].lower()

    # separar por espacios, guiones, underscores, etc.
    partes = re.split(r"[ _\-]+", nombre)

    # buscar coincidencia exacta
    for parte in partes:
        if parte in años:
            return parte  # retorna el año encontrado

    # búsqueda más flexible: " - diciembre 2012"
    for año in años:
        if año in nombre:
            return año

    return None

import os

def listar_todos_los_root_excels(root_excels):
    excels = []
    for root, dirs, files in os.walk(root_excels):
        for file in files:
            if file.lower().endswith(('.xlsx', '.xls')):
                excels.append(os.path.join(root, file))
    return excels

# %%
rutas = listar_todos_los_root_excels(root_excels)
rutas[:4]
# Out:
# ['C:\\Users\\hsakurada\\Desktop\\ESTUDIO\\wea\\CMS-PRUEBA-TECNICA\\descargas\\2020\\Base de Datos de Transporte Público - Abril 2021.xlsx',
#  'C:\\Users\\hsakurada\\Desktop\\ESTUDIO\\wea\\CMS-PRUEBA-TECNICA\\descargas\\2020\\Base de Datos de Transporte Público - Agosto 2021.xlsx',
#  'C:\\Users\\hsakurada\\Desktop\\ESTUDIO\\wea\\CMS-PRUEBA-TECNICA\\descargas\\2020\\Base de Datos de Transporte Público - Diciembre 2021.xlsx',
#  'C:\\Users\\hsakurada\\Desktop\\ESTUDIO\\wea\\CMS-PRUEBA-TECNICA\\descargas\\2020\\Base de Datos de Transporte Público - Enero 2021.xlsx']

# %%
import os
import re
import unicodedata
import pandas as pd
from rapidfuzz import fuzz, process as fuzzprocess

# ============================================================
# PRECOMPILAR REGEX (20x más rápido)
# ============================================================
_re_non_alnum = re.compile(r"[^0-9a-z]+")
_re_multi_unders = re.compile(r"_+")

# ============================================================
# NORMALIZACIÓN RÁPIDA
# ============================================================
def normalize_fast(text: str) -> str:
    """Normaliza texto MUY rápido: sin acentos, minúsculas, underscores limpios."""
    if not isinstance(text, str):
        return text

    text = unicodedata.normalize("NFKD", text)
    text = "".join(c for c in text if not unicodedata.combining(c))
    text = text.lower()

    text = _re_non_alnum.sub("_", text)
    text = _re_multi_unders.sub("_", text)
    return text.strip("_")


def normalize_sheet_name(name):
    """Normaliza y singulariza para evitar 'vehiculos' / 'vehiculo'."""
    norm = normalize_fast(name)
    # singularización simple
    if norm.endswith("es") and len(norm) > 3:
        norm = norm[:-2]
    elif norm.endswith("s") and len(norm) > 2:
        norm = norm[:-1]
    return norm


def normalize_column_name(name):
    return normalize_fast(name)


# ============================================================
# UNIFICADOR DE COLUMNAS (OPTIMIZADO)
# ============================================================
def unify_column_names_fast(dfs, cutoff=0.75):
    """
    Unifica nombres de columnas con:
    - normalización
    - bucketing por prefijo (reduce fuzzy match 80%)
    """

    # --------------- recolectar columnas normalizadas ---------------
    col_master = set()
    normalized_per_df = []

    for df in dfs:
        norm_cols = [normalize_column_name(c) for c in df.columns]
        normalized_per_df.append(norm_cols)
        col_master.update(norm_cols)

    col_master = list(col_master)

    # --------------- buckets por primeros 4 caracteres ---------------
    buckets = {}
    for col in col_master:
        key = col[:4]
        buckets.setdefault(key, []).append(col)

    # --------------- renombrar DataFrames ---------------
    results = []
    for df, norm_cols in zip(dfs, normalized_per_df):
        rename_map = {}
        for orig, norm in zip(df.columns, norm_cols):
            candidates = buckets.get(norm[:4], [])

            if norm in candidates:
                rename_map[orig] = norm
                continue

            # fuzzy solo cuando necesario
            best, score = fuzzprocess.extractOne(norm, candidates, scorer=fuzz.ratio) or (None, 0)
            rename_map[orig] = best if score >= cutoff * 100 else norm

        results.append(df.rename(columns=rename_map))

    return results


# ============================================================
# AGRUPADOR DE HOJAS SIMILARES (vehiculo / vehiculos / vehículo)
# ============================================================
def agrupar_nombres_hoja(sheet_names, cutoff=80):
    """
    Une nombres similares en un solo grupo:
    Ej: vehiculo, vehiculos, vehículo → vehiculo
    """
    grupos = {}
    canonicos = []

    for name in sheet_names:
        norm = normalize_sheet_name(name)

        if canonicos:
            match = fuzzprocess.extractOne(norm, canonicos, scorer=fuzz.ratio)
            if match and match[1] >= cutoff:
                grupos[match[0]].append(name)
                continue

        grupos[norm] = [name]
        canonicos.append(norm)

    return grupos

# %%
def escanear_hojas(lista_rutas, verbose=True):
    all_sheet_names = []
    file_sheets = {}

    for ruta in lista_rutas:
        try:
            xls = pd.ExcelFile(ruta)
            nombres = xls.sheet_names
            file_sheets[ruta] = nombres
            all_sheet_names.extend(nombres)

            if verbose:
                print(f"📄 {os.path.basename(ruta)}")
                print(f"   → Hojas: {nombres}")

        except Exception as e:
            print(f"❌ Error leyendo {ruta}: {e}")
            continue

    return file_sheets, all_sheet_names

# %%
def obtener_grupo_final(nombre_hoja, hoja_norm, equivalencias):
    for canon, miembros in equivalencias.items():
        if nombre_hoja in miembros or hoja_norm == canon:
            return canon
    return hoja_norm  # si no encuentra grupo

# %%
def agrupar_hojas(all_sheet_names, cutoff=80, verbose=True):
    equivalencias = agrupar_nombres_hoja(all_sheet_names, cutoff=cutoff)

    if verbose:
        print("\n📌 Grupos detectados:")
        for canon, items in equivalencias.items():
            print(f"   • {canon}: {items}")

    return equivalencias

# %%
def previsualizar_columnas(file_sheets, equivalencias, n_rows_preview=5, verbose=True):
    columnas_por_grupo = {}

    for ruta, hojas in file_sheets.items():
        try:
            xls = pd.ExcelFile(ruta)
        except:
            continue

        for hoja_original in hojas:
            hoja_norm = normalize_sheet_name(hoja_original)
            grupo = obtener_grupo_final(hoja_original, hoja_norm, equivalencias)

            try:
                df_preview = xls.parse(hoja_original, nrows=n_rows_preview)
            except:
                continue

            columnas = list(df_preview.columns)

            columnas_por_grupo.setdefault(grupo, [])
            columnas_por_grupo[grupo].append({
                "archivo": os.path.basename(ruta),
                "hoja": hoja_original,
                "columnas": columnas
            })

    if verbose:
        print("\n🔎 PREVISUALIZACIÓN DE COLUMNAS POR GRUPO")
        for grupo, items in columnas_por_grupo.items():
            print(f"\n=== Grupo: {grupo} ===")
            for entry in items:
                print(f"  • Archivo: {entry['archivo']}")
                print(f"    Hoja:    {entry['hoja']}")
                print(f"    Columnas: {entry['columnas']}")

    return columnas_por_grupo

# %%
def obtener_grupo_final(nombre_hoja, hoja_norm, equivalencias):
    for canon, miembros in equivalencias.items():
        if nombre_hoja in miembros or hoja_norm == canon:
            return canon
    return hoja_norm

# %%
def procesar_archivos(file_sheets, equivalencias, verbose=True):
    grupos = {}

    for ruta, hojas in file_sheets.items():
        nombre_archivo = os.path.basename(ruta)
        mes = extraer_mes_nomb_excel(nombre_archivo)
        año = extraer_año(nombre_archivo)

        if verbose:
            print(f"\n📂 Procesando {nombre_archivo}")

        xls = pd.ExcelFile(ruta)

        for hoja_original in hojas:
            hoja_norm = normalize_sheet_name(hoja_original)
            hoja_final = obtener_grupo_final(hoja_original, hoja_norm, equivalencias)

            if verbose:
                print(f"   📝 {hoja_original}  → grupo={hoja_final}")

            try:
                df = xls.parse(hoja_original)
            except Exception as e:
                print(f"   ❌ Error leyendo {hoja_original}: {e}")
                continue

            df["mes"] = mes
            df["año"] = año

            grupos.setdefault(hoja_final, []).append(df)

    return grupos

# %%
# 1) Escanear nombres de hojas
file_sheets, all_sheet_names = escanear_hojas(rutas)

# 2) Agrupar por fuzzy
equivalencias = agrupar_hojas(all_sheet_names)
# Out:
# 📄 Base de Datos de Transporte Público - Abril 2021.xlsx
#    → Hojas: ['Servicios', 'Replegal', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Agosto 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorrido', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazado']
# 📄 Base de Datos de Transporte Público - Enero 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Febrero 2021.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículo', 'O-D Recorrido', 'Trazado']
# 📄 Base de Datos de Transporte Público - Julio 2021.xlsx
#    → Hojas: ['Servicios', 'Representantes Legales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Junio 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados ']
# 📄 Base de Datos de Transporte Público - Marzo 2021.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehiculos vig', 'O-D Recorrido', 'Trazados']
# 📄 Base de Datos de Transporte Público - Mayo 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Noviembre 2021.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Octubre 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Septiembre 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Abril 2021.xlsx
#    → Hojas: ['Servicios', 'Replegal', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Agosto 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorrido', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazado']
# 📄 Base de Datos de Transporte Público - Enero 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Febrero 2021.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículo', 'O-D Recorrido', 'Trazado']
# 📄 Base de Datos de Transporte Público - Julio 2021.xlsx
#    → Hojas: ['Servicios', 'Representantes Legales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Junio 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados ']
# 📄 Base de Datos de Transporte Público - Marzo 2021.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehiculos vig', 'O-D Recorrido', 'Trazados']
# 📄 Base de Datos de Transporte Público - Mayo 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Noviembre 2021.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Octubre 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Septiembre 2021.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de datos de Transporte Público - Abril 2022.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazadosok']
# 📄 Base de Datos de Transporte Público - Agosto 2022.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2022.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Enero 2022.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazado']
# 📄 Base de Datos de Transporte Público - Febrero 2022.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Julio 2022.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículo', 'O_D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Junio 2022.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos_Vigentes', 'O-D Recorridos', 'Trazados']
# 📄 Base de datos de Transporte Público - Marzo 2022.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo_vigente ', 'O-D Recorridos', 'Trazado ']
# 📄 Base de Datos de Transporte Público - Mayo 2022.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Noviembre 2022.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Octubre 2022.xlsx
#    → Hojas: ['Servicio', 'RepLegalok', 'Vehiculos', 'O-D Recorridos', 'Trazados ']
# 📄 Base de Datos de Transporte Público - Septiembre 2022.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Abril 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazado']
# 📄 Base de Datos de Transporte Público - Agosto 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Enero 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazado']
# 📄 Base de Datos de Transporte Público - Febrero 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorrido', 'Trazados']
# 📄 Base de Datos de Transporte Público - Julio 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Junio 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Marzo 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazado']
# 📄 Base de Datos de Transporte Público - Mayo 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorrido', 'Trazados']
# 📄 Base de Datos de Transporte Público - Noviembre 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculo', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Octubre 2023.xlsx
#    → Hojas: ['Servicio', 'RepLegal', 'Vehiculos', 'O-D Recorrido', 'Trazados']
# 📄 Base de Datos de Transporte Público - Septiembre 2023.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculo', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Abril 2024.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Agosto 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Diciembre 2024.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Enero 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Febrero 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazado']
# 📄 Transporte Público - Julio 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Junio 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Marzo 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículo', 'O-D Recorridos', 'Trazado_ok']
# 📄 Transporte Público - Mayo 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículosok', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Noviembre 2024.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Tarazados']
# 📄 Transporte Público - Octubre 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Septiembre 2024.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Abril 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Agosto 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Enero 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Julio 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Junio 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos ', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Marzo 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Mayo 2025.xlsx
#    → Hojas: ['Servicio', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Octubre 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehículos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público - Septiembre 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Transporte Público- Febrero 2025.xlsx
#    → Hojas: ['Servicios', 'RepLegales', 'Vehiculos', 'O-D Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2012.xlsx
#    → Hojas: ['Vehiculos']
# 📄 Base de Datos de Transporte Público - Diciembre 2013.xlsx
#    → Hojas: ['Servicios', 'RepresentantesLegales', 'Vehiculos', 'Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2014.xlsx
#    → Hojas: ['ResponsablesdeServicio', 'RepresentantesLegales', 'vehiculo', 'Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2015.xlsx
#    → Hojas: ['ResponsablesdeServicio', 'RepresentantesLegales', 'vehiculo', 'Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2016.xlsx
#    → Hojas: ['Servicios', 'RepresentantesLegales', 'Vehiculos', 'Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2017.xlsx
#    → Hojas: ['Servicios', 'Representantes Legales', 'Vehículos', 'Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2018.xlsx
#    → Hojas: ['Servicios', 'Representantes Legales', 'Vehiculos', 'Recorridos', 'Trazados']
# 📄 Base de Datos de Transporte Público - Diciembre 2019.xlsx
#    → Hojas: ['Servicios', 'Representantes Legales', 'Vehiculos', 'Recorridos', 'Trazados']
#
# 📌 Grupos detectados:
#    • servicio: ['Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicio', 'Servicio', 'Servicio', 'Servicio', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicio', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicio', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios', 'Servicios']
#    • replegal: ['Replegal', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'Replegal', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegalok', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegal', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales', 'RepLegales']
#    • vehiculo: ['Vehículos', 'Vehículo', 'Vehículo', 'Vehiculos', 'Vehículo', 'Vehículos', 'Vehiculos', 'Vehiculos', 'Vehículo', 'Vehiculos', 'Vehículos', 'Vehículos', 'Vehículo', 'Vehículo', 'Vehiculos', 'Vehículo', 'Vehículos', 'Vehiculos', 'Vehiculos', 'Vehículo', 'Vehiculos', 'Vehículos', 'Vehículo', 'Vehículos', 'Vehículo', 'Vehiculos', 'Vehiculos', 'Vehículo', 'Vehiculos', 'Vehículo', 'Vehiculos', 'Vehículos', 'Vehiculos', 'Vehículo', 'Vehiculos', 'Vehículo', 'Vehículo', 'Vehículo', 'Vehículos', 'Vehiculos', 'Vehículo', 'Vehiculo', 'Vehiculos', 'Vehiculo', 'Vehículo', 'Vehículos', 'Vehiculos', 'Vehiculos', 'Vehículos', 'Vehículos', 'Vehiculos', 'Vehículo', 'Vehículosok', 'Vehículos', 'Vehiculos', 'Vehiculos', 'Vehículos', 'Vehículos', 'Vehiculos', 'Vehículos', 'Vehículos ', 'Vehículos', 'Vehículos', 'Vehículos', 'Vehiculos', 'Vehiculos', 'Vehiculos', 'Vehiculos', 'vehiculo', 'vehiculo', 'Vehiculos', 'Vehículos', 'Vehiculos', 'Vehiculos']
#    • o_d_recorrido: ['O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O_D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorrido', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'O-D Recorridos', 'Recorridos', 'Recorridos', 'Recorridos', 'Recorridos', 'Recorridos', 'Recorridos', 'Recorridos']
#    • trazado: ['Trazados', 'Trazados', 'Trazado', 'Trazados', 'Trazado', 'Trazados', 'Trazados ', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazado', 'Trazados', 'Trazado', 'Trazados', 'Trazados ', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazadosok', 'Trazados', 'Trazados', 'Trazado', 'Trazados', 'Trazados', 'Trazados', 'Trazado ', 'Trazados', 'Trazados', 'Trazados ', 'Trazados', 'Trazado', 'Trazados', 'Trazados', 'Trazado', 'Trazados', 'Trazados', 'Trazados', 'Trazado', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazado', 'Trazados', 'Trazados', 'Trazado_ok', 'Trazados', 'Tarazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados', 'Trazados']
#    • representantes_legal: ['Representantes Legales', 'Representantes Legales', 'RepresentantesLegales', 'RepresentantesLegales', 'RepresentantesLegales', 'RepresentantesLegales', 'Representantes Legales', 'Representantes Legales', 'Representantes Legales']
#    • vehiculos_vig: ['Vehiculos vig', 'Vehiculos vig', 'Vehículos_Vigentes', 'Vehículo_vigente ']
#    • responsablesdeservicio: ['ResponsablesdeServicio', 'ResponsablesdeServicio']

# %%
ASDASD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ASDASD
#
# NameError: name 'ASDASD' is not defined

# %%
# 3) Previsualizar las columnas por grupo (VERIFICACIÓN MANUAL)
columnas_preview = previsualizar_columnas(file_sheets, equivalencias)

# → Aquí puedes corregir equivalencias manualmente

# 4) Procesar realmente
grupos = procesar_archivos(file_sheets, equivalencias)
